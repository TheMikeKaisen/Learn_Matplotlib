# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
r = np.random.randint(10, 300, 100)
r
# Out:
# array([261, 252, 106,  60, 186, 241, 154, 145,  21, 231, 206, 256,  60,
#         61,  93, 241, 217, 279, 223,  68, 229,  45, 264,  93, 162, 195,
#         39, 192,  89,  56, 147, 107, 188, 279,  80, 203,  91, 189, 286,
#        210, 149, 183, 172, 116,  46, 175, 291,  34,  85, 264, 164, 194,
#        286, 221, 225, 227,  69, 100,  27, 120,  15, 168, 220, 279,  72,
#        176, 128, 291, 253, 209, 116,  16, 159, 141,  28,  80, 170, 188,
#        179,  52,  94, 219,  14,  64, 204,  21, 136,  79, 141,  38, 216,
#         29, 114,  61, 107, 222,  25, 233, 162, 135])

# %%
numbers = [12, 56, 58, 28, 14, 32, 14, 57, 17, 44, 31, 18, 11, 33, 13, 49, 46,
       14, 19, 54, 44, 27, 18, 15, 18, 33, 57, 21, 57, 51, 10, 47, 47, 32,
       34, 51, 42, 39, 10, 54, 11, 35, 59, 35, 41, 36, 42, 42, 33, 46]

# given totally nonsense data
plt.hist(numbers, color='b')
plt.xlabel("numbers")
plt.ylabel("more numbers")
plt.title("Amazing title #2")
plt.show()

# %%
# kind of sensible data....maybe

numbers = [12, 56, 58, 28, 14, 32, 14, 57, 17, 44, 31, 18, 11, 33, 13, 49, 46,
       14, 19, 54, 44, 27, 18, 15, 18, 33, 57, 21, 57, 51, 10, 47, 47, 32,
       34, 51, 42, 39, 10, 54, 11, 35, 59, 35, 41, 36, 42, 42, 33, 46]

# create bins
bins = [10, 20, 30, 40, 50, 60]
plt.hist(numbers, bins=bins, color='b')
plt.xlabel("numbers")
plt.ylabel("more numbers")
plt.title("Amazing title #2")
plt.show()

# %%
# 100 numbers between 0 and 300
numbers = [261, 252, 106,  60, 186, 241, 154, 145,  21, 231, 206, 256,  60,
        61,  93, 241, 217, 279, 223,  68, 229,  45, 264,  93, 162, 195,
        39, 192,  89,  56, 147, 107, 188, 279,  80, 203,  91, 189, 286,
       210, 149, 183, 172, 116,  46, 175, 291,  34,  85, 264, 164, 194,
       286, 221, 225, 227,  69, 100,  27, 120,  15, 168, 220, 279,  72,
       176, 128, 291, 253, 209, 116,  16, 159, 141,  28,  80, 170, 188,
       179,  52,  94, 219,  14,  64, 204,  21, 136,  79, 141,  38, 216,
        29, 114,  61, 107, 222,  25, 233, 162, 135]

# create bins as auto and provide a range
plt.hist(numbers,"auto", range=(0,100), color='b')
plt.xlabel("numbers")
plt.ylabel("more numbers")
plt.title("Amazing title #2")
plt.show()

# %% [markdown]
# ### cumulative

# %%
# 50 numbers between 0 and 60
numbers = [12, 56, 58, 28, 14, 32, 14, 57, 17, 44, 31, 18, 11, 33, 13, 49, 46,
       14, 19, 54, 44, 27, 18, 15, 18, 33, 57, 21, 57, 51, 10, 47, 47, 32,
       34, 51, 42, 39, 10, 54, 11, 35, 59, 35, 41, 36, 42, 42, 33, 46]
bins = [10, 20, 30, 40, 50, 60]

# create bins as auto and provide a range
plt.hist(numbers,bins=bins, color='b', cumulative=-1)
plt.xlabel("numbers")
plt.ylabel("more numbers")
plt.title("Amazing title #2")
plt.show()

# %%
# 50 numbers between 0 and 60
numbers = [12, 56, 58, 28, 14, 32, 14, 57, 17, 44, 31, 18, 11, 33, 13, 49, 46,
       14, 19, 54, 44, 27, 18, 15, 18, 33, 57, 21, 57, 51, 10, 47, 47, 32,
       34, 51, 42, 39, 10, 54, 11, 35, 59, 35, 41, 36, 42, 42, 33, 46]
bins = [10, 20, 30, 40, 50, 60]

# create bins as auto and provide a range
plt.hist(numbers,bins=bins, color='b', cumulative=1)
plt.xlabel("numbers")
plt.ylabel("more numbers")
plt.title("Amazing title #2")
plt.show()

# %% [markdown]
# ## bottom

# %%
# 50 numbers between 0 and 60
numbers = [12, 56, 58, 28, 14, 32, 14, 57, 17, 44, 31, 18, 11, 33, 13, 49, 46,
       14, 19, 54, 44, 27, 18, 15, 18, 33, 57, 21, 57, 51, 10, 47, 47, 32,
       34, 51, 42, 39, 10, 54, 11, 35, 59, 35, 41, 36, 42, 42, 33, 46]
bins = [10, 20, 30, 40, 50, 60]

# create bins as auto and provide a range
plt.hist(numbers,bins=bins, bottom=10)
plt.xlabel("numbers")
plt.ylabel("more numbers")
plt.title("Amazing title #2")
plt.show()

# %%
# 50 numbers between 0 and 60
numbers = [12, 56, 58, 28, 14, 32, 14, 57, 17, 44, 31, 18, 11, 33, 13, 49, 46,
       14, 19, 54, 44, 27, 18, 15, 18, 33, 57, 21, 57, 51, 10, 47, 47, 32,
       34, 51, 42, 39, 10, 54, 11, 35, 59, 35, 41, 36, 42, 42, 33, 46]
bins = [10, 20, 30, 40, 50, 60]

# create bins as auto and provide a range
plt.hist(numbers,bins=bins, bottom=10, histtype='stepfilled')
''' 
bar(default)
barstacked
step
stepfilled
'''
plt.xlabel("numbers")
plt.ylabel("more numbers")
plt.title("Amazing title #2")
plt.show()

# %% [markdown]
# ### histtype
